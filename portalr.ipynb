# %% [markdown]
# #### Population dynamics of small mammals at the Portal Project

# %%
library(ggplot2)
abund = portalr::abundance(shape="flat")
ggplot(abund, aes(x = period, y = abundance, color = species)) +
  geom_line() + theme(legend.position="none")
# Out:
# Loading in data version 1.54.0
# Joining, by = c("month", "day", "year", "period", "plot")
# Joining, by = "period"
# Joining, by = c("year", "month", "plot")
# plot without title
